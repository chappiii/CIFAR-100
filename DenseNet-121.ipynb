# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# 1. Load CIFAR-100 data
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')

# 2. One-hot encode the labels
enc = OneHotEncoder(sparse_output=False)
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

# 3. Define preprocessing function (resize + normalize)
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# 4. Shuffle training data before splitting
train_indices = np.arange(len(X_train))
np.random.shuffle(train_indices)

X_train = X_train[train_indices]
y_train = y_train[train_indices]

# 5. Compute split sizes
val_size = int(0.1 * len(X_train))
X_val = X_train[:val_size]
y_val = y_train[:val_size]
X_train = X_train[val_size:]
y_train = y_train[val_size:]

# 6. Create tf.data.Dataset pipelines
batch_size = 16

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=1000)
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_dataset = val_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size)
val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_dataset = test_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# from preprocess import get_cifar100_datasets

# train_ds, val_ds, test_ds = get_cifar100_datasets(image_size=(128, 128), batch_size=32)

# %%
def conv_block(x, growth_rate):
    x1 = layers.BatchNormalization()(x)
    x1 = layers.Activation('relu')(x1)
    x1 = layers.Conv2D(4 * growth_rate, (1, 1), use_bias=False)(x1)

    x1 = layers.BatchNormalization()(x1)
    x1 = layers.Activation('relu')(x1)
    x1 = layers.Conv2D(growth_rate, (3, 3), padding='same', use_bias=False)(x1)

    x = layers.Concatenate()([x, x1])
    return x

def dense_block(x, layers_count, growth_rate):
    for _ in range(layers_count):
        x = conv_block(x, growth_rate)
    return x

def transition_layer(x, compression=0.5):
    reduced_filters = int(tf.keras.backend.int_shape(x)[-1] * compression)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(reduced_filters, (1, 1), use_bias=False)(x)
    x = layers.AveragePooling2D((2, 2), strides=2)(x)
    return x

def build_densenet121(input_shape=(128, 128, 3), num_classes=100):
    growth_rate = 32
    block_layers = [6, 12, 24, 16]

    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=2, padding='same')(x)

    for i, num_layers in enumerate(block_layers):
        x = dense_block(x, num_layers, growth_rate)
        if i != len(block_layers) - 1:
            x = transition_layer(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs, name="DenseNet121_Custom")
    return model

# %%
model = build_densenet121()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "DenseNet121_Custom"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_960 (Conv2D)             (None, 64, 64, 64)   9408        input_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_968 (BatchN (None, 64, 64, 64)   256         conv2d_960[0][0]
# __________________________________________________________________________________________________
# activation_968 (Activation)     (None, 64, 64, 64)   0           batch_normalization_968[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_968[0][0]
# __________________________________________________________________________________________________
# batch_normalization_969 (BatchN (None, 32, 32, 64)   256         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_969 (Activation)     (None, 32, 32, 64)   0           batch_normalization_969[0][0]
# __________________________________________________________________________________________________
# conv2d_961 (Conv2D)             (None, 32, 32, 128)  8192        activation_969[0][0]
# __________________________________________________________________________________________________
# batch_normalization_970 (BatchN (None, 32, 32, 128)  512         conv2d_961[0][0]
# __________________________________________________________________________________________________
# activation_970 (Activation)     (None, 32, 32, 128)  0           batch_normalization_970[0][0]
# __________________________________________________________________________________________________
# conv2d_962 (Conv2D)             (None, 32, 32, 32)   36864       activation_970[0][0]
# __________________________________________________________________________________________________
# concatenate_464 (Concatenate)   (None, 32, 32, 96)   0           max_pooling2d_8[0][0]
#                                                                  conv2d_962[0][0]
# __________________________________________________________________________________________________
# batch_normalization_971 (BatchN (None, 32, 32, 96)   384         concatenate_464[0][0]
# __________________________________________________________________________________________________
# activation_971 (Activation)     (None, 32, 32, 96)   0           batch_normalization_971[0][0]
# __________________________________________________________________________________________________
# conv2d_963 (Conv2D)             (None, 32, 32, 128)  12288       activation_971[0][0]
# __________________________________________________________________________________________________
# batch_normalization_972 (BatchN (None, 32, 32, 128)  512         conv2d_963[0][0]
# __________________________________________________________________________________________________
# activation_972 (Activation)     (None, 32, 32, 128)  0           batch_normalization_972[0][0]
# __________________________________________________________________________________________________
# conv2d_964 (Conv2D)             (None, 32, 32, 32)   36864       activation_972[0][0]
# __________________________________________________________________________________________________
# concatenate_465 (Concatenate)   (None, 32, 32, 128)  0           concatenate_464[0][0]
#                                                                  conv2d_964[0][0]
# __________________________________________________________________________________________________
# batch_normalization_973 (BatchN (None, 32, 32, 128)  512         concatenate_465[0][0]
# __________________________________________________________________________________________________
# activation_973 (Activation)     (None, 32, 32, 128)  0           batch_normalization_973[0][0]
# __________________________________________________________________________________________________
# conv2d_965 (Conv2D)             (None, 32, 32, 128)  16384       activation_973[0][0]
# __________________________________________________________________________________________________
# batch_normalization_974 (BatchN (None, 32, 32, 128)  512         conv2d_965[0][0]
# __________________________________________________________________________________________________
# activation_974 (Activation)     (None, 32, 32, 128)  0           batch_normalization_974[0][0]
# __________________________________________________________________________________________________
# conv2d_966 (Conv2D)             (None, 32, 32, 32)   36864       activation_974[0][0]
# __________________________________________________________________________________________________
# concatenate_466 (Concatenate)   (None, 32, 32, 160)  0           concatenate_465[0][0]
#                                                                  conv2d_966[0][0]
# __________________________________________________________________________________________________
# batch_normalization_975 (BatchN (None, 32, 32, 160)  640         concatenate_466[0][0]
# __________________________________________________________________________________________________
# activation_975 (Activation)     (None, 32, 32, 160)  0           batch_normalization_975[0][0]
# __________________________________________________________________________________________________
# conv2d_967 (Conv2D)             (None, 32, 32, 128)  20480       activation_975[0][0]
# __________________________________________________________________________________________________
# batch_normalization_976 (BatchN (None, 32, 32, 128)  512         conv2d_967[0][0]
# __________________________________________________________________________________________________
# activation_976 (Activation)     (None, 32, 32, 128)  0           batch_normalization_976[0][0]
# __________________________________________________________________________________________________
# conv2d_968 (Conv2D)             (None, 32, 32, 32)   36864       activation_976[0][0]
# __________________________________________________________________________________________________
# concatenate_467 (Concatenate)   (None, 32, 32, 192)  0           concatenate_466[0][0]
#                                                                  conv2d_968[0][0]
# __________________________________________________________________________________________________
# batch_normalization_977 (BatchN (None, 32, 32, 192)  768         concatenate_467[0][0]
# __________________________________________________________________________________________________
# activation_977 (Activation)     (None, 32, 32, 192)  0           batch_normalization_977[0][0]
# __________________________________________________________________________________________________
# conv2d_969 (Conv2D)             (None, 32, 32, 128)  24576       activation_977[0][0]
# __________________________________________________________________________________________________
# batch_normalization_978 (BatchN (None, 32, 32, 128)  512         conv2d_969[0][0]
# __________________________________________________________________________________________________
# activation_978 (Activation)     (None, 32, 32, 128)  0           batch_normalization_978[0][0]
# __________________________________________________________________________________________________
# conv2d_970 (Conv2D)             (None, 32, 32, 32)   36864       activation_978[0][0]
# __________________________________________________________________________________________________
# concatenate_468 (Concatenate)   (None, 32, 32, 224)  0           concatenate_467[0][0]
#                                                                  conv2d_970[0][0]
# __________________________________________________________________________________________________
# batch_normalization_979 (BatchN (None, 32, 32, 224)  896         concatenate_468[0][0]
# __________________________________________________________________________________________________
# activation_979 (Activation)     (None, 32, 32, 224)  0           batch_normalization_979[0][0]
# __________________________________________________________________________________________________
# conv2d_971 (Conv2D)             (None, 32, 32, 128)  28672       activation_979[0][0]
# __________________________________________________________________________________________________
# batch_normalization_980 (BatchN (None, 32, 32, 128)  512         conv2d_971[0][0]
# __________________________________________________________________________________________________
# activation_980 (Activation)     (None, 32, 32, 128)  0           batch_normalization_980[0][0]
# __________________________________________________________________________________________________
# conv2d_972 (Conv2D)             (None, 32, 32, 32)   36864       activation_980[0][0]
# __________________________________________________________________________________________________
# concatenate_469 (Concatenate)   (None, 32, 32, 256)  0           concatenate_468[0][0]
#                                                                  conv2d_972[0][0]
# __________________________________________________________________________________________________
# batch_normalization_981 (BatchN (None, 32, 32, 256)  1024        concatenate_469[0][0]
# __________________________________________________________________________________________________
# activation_981 (Activation)     (None, 32, 32, 256)  0           batch_normalization_981[0][0]
# __________________________________________________________________________________________________
# conv2d_973 (Conv2D)             (None, 32, 32, 128)  32768       activation_981[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_24 (AveragePo (None, 16, 16, 128)  0           conv2d_973[0][0]
# __________________________________________________________________________________________________
# batch_normalization_982 (BatchN (None, 16, 16, 128)  512         average_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# activation_982 (Activation)     (None, 16, 16, 128)  0           batch_normalization_982[0][0]
# __________________________________________________________________________________________________
# conv2d_974 (Conv2D)             (None, 16, 16, 128)  16384       activation_982[0][0]
# __________________________________________________________________________________________________
# batch_normalization_983 (BatchN (None, 16, 16, 128)  512         conv2d_974[0][0]
# __________________________________________________________________________________________________
# activation_983 (Activation)     (None, 16, 16, 128)  0           batch_normalization_983[0][0]
# __________________________________________________________________________________________________
# conv2d_975 (Conv2D)             (None, 16, 16, 32)   36864       activation_983[0][0]
# __________________________________________________________________________________________________
# concatenate_470 (Concatenate)   (None, 16, 16, 160)  0           average_pooling2d_24[0][0]
#                                                                  conv2d_975[0][0]
# __________________________________________________________________________________________________
# batch_normalization_984 (BatchN (None, 16, 16, 160)  640         concatenate_470[0][0]
# __________________________________________________________________________________________________
# activation_984 (Activation)     (None, 16, 16, 160)  0           batch_normalization_984[0][0]
# __________________________________________________________________________________________________
# conv2d_976 (Conv2D)             (None, 16, 16, 128)  20480       activation_984[0][0]
# __________________________________________________________________________________________________
# batch_normalization_985 (BatchN (None, 16, 16, 128)  512         conv2d_976[0][0]
# __________________________________________________________________________________________________
# activation_985 (Activation)     (None, 16, 16, 128)  0           batch_normalization_985[0][0]
# __________________________________________________________________________________________________
# conv2d_977 (Conv2D)             (None, 16, 16, 32)   36864       activation_985[0][0]
# __________________________________________________________________________________________________
# concatenate_471 (Concatenate)   (None, 16, 16, 192)  0           concatenate_470[0][0]
#                                                                  conv2d_977[0][0]
# __________________________________________________________________________________________________
# batch_normalization_986 (BatchN (None, 16, 16, 192)  768         concatenate_471[0][0]
# __________________________________________________________________________________________________
# activation_986 (Activation)     (None, 16, 16, 192)  0           batch_normalization_986[0][0]
# __________________________________________________________________________________________________
# conv2d_978 (Conv2D)             (None, 16, 16, 128)  24576       activation_986[0][0]
# __________________________________________________________________________________________________
# batch_normalization_987 (BatchN (None, 16, 16, 128)  512         conv2d_978[0][0]
# __________________________________________________________________________________________________
# activation_987 (Activation)     (None, 16, 16, 128)  0           batch_normalization_987[0][0]
# __________________________________________________________________________________________________
# conv2d_979 (Conv2D)             (None, 16, 16, 32)   36864       activation_987[0][0]
# __________________________________________________________________________________________________
# concatenate_472 (Concatenate)   (None, 16, 16, 224)  0           concatenate_471[0][0]
#                                                                  conv2d_979[0][0]
# __________________________________________________________________________________________________
# batch_normalization_988 (BatchN (None, 16, 16, 224)  896         concatenate_472[0][0]
# __________________________________________________________________________________________________
# activation_988 (Activation)     (None, 16, 16, 224)  0           batch_normalization_988[0][0]
# __________________________________________________________________________________________________
# conv2d_980 (Conv2D)             (None, 16, 16, 128)  28672       activation_988[0][0]
# __________________________________________________________________________________________________
# batch_normalization_989 (BatchN (None, 16, 16, 128)  512         conv2d_980[0][0]
# __________________________________________________________________________________________________
# activation_989 (Activation)     (None, 16, 16, 128)  0           batch_normalization_989[0][0]
# __________________________________________________________________________________________________
# conv2d_981 (Conv2D)             (None, 16, 16, 32)   36864       activation_989[0][0]
# __________________________________________________________________________________________________
# concatenate_473 (Concatenate)   (None, 16, 16, 256)  0           concatenate_472[0][0]
#                                                                  conv2d_981[0][0]
# __________________________________________________________________________________________________
# batch_normalization_990 (BatchN (None, 16, 16, 256)  1024        concatenate_473[0][0]
# __________________________________________________________________________________________________
# activation_990 (Activation)     (None, 16, 16, 256)  0           batch_normalization_990[0][0]
# __________________________________________________________________________________________________
# conv2d_982 (Conv2D)             (None, 16, 16, 128)  32768       activation_990[0][0]
# __________________________________________________________________________________________________
# batch_normalization_991 (BatchN (None, 16, 16, 128)  512         conv2d_982[0][0]
# __________________________________________________________________________________________________
# activation_991 (Activation)     (None, 16, 16, 128)  0           batch_normalization_991[0][0]
# __________________________________________________________________________________________________
# conv2d_983 (Conv2D)             (None, 16, 16, 32)   36864       activation_991[0][0]
# __________________________________________________________________________________________________
# concatenate_474 (Concatenate)   (None, 16, 16, 288)  0           concatenate_473[0][0]
#                                                                  conv2d_983[0][0]
# __________________________________________________________________________________________________
# batch_normalization_992 (BatchN (None, 16, 16, 288)  1152        concatenate_474[0][0]
# __________________________________________________________________________________________________
# activation_992 (Activation)     (None, 16, 16, 288)  0           batch_normalization_992[0][0]
# __________________________________________________________________________________________________
# conv2d_984 (Conv2D)             (None, 16, 16, 128)  36864       activation_992[0][0]
# __________________________________________________________________________________________________
# batch_normalization_993 (BatchN (None, 16, 16, 128)  512         conv2d_984[0][0]
# __________________________________________________________________________________________________
# activation_993 (Activation)     (None, 16, 16, 128)  0           batch_normalization_993[0][0]
# __________________________________________________________________________________________________
# conv2d_985 (Conv2D)             (None, 16, 16, 32)   36864       activation_993[0][0]
# __________________________________________________________________________________________________
# concatenate_475 (Concatenate)   (None, 16, 16, 320)  0           concatenate_474[0][0]
#                                                                  conv2d_985[0][0]
# __________________________________________________________________________________________________
# batch_normalization_994 (BatchN (None, 16, 16, 320)  1280        concatenate_475[0][0]
# __________________________________________________________________________________________________
# activation_994 (Activation)     (None, 16, 16, 320)  0           batch_normalization_994[0][0]
# __________________________________________________________________________________________________
# conv2d_986 (Conv2D)             (None, 16, 16, 128)  40960       activation_994[0][0]
# __________________________________________________________________________________________________
# batch_normalization_995 (BatchN (None, 16, 16, 128)  512         conv2d_986[0][0]
# __________________________________________________________________________________________________
# activation_995 (Activation)     (None, 16, 16, 128)  0           batch_normalization_995[0][0]
# __________________________________________________________________________________________________
# conv2d_987 (Conv2D)             (None, 16, 16, 32)   36864       activation_995[0][0]
# __________________________________________________________________________________________________
# concatenate_476 (Concatenate)   (None, 16, 16, 352)  0           concatenate_475[0][0]
#                                                                  conv2d_987[0][0]
# __________________________________________________________________________________________________
# batch_normalization_996 (BatchN (None, 16, 16, 352)  1408        concatenate_476[0][0]
# __________________________________________________________________________________________________
# activation_996 (Activation)     (None, 16, 16, 352)  0           batch_normalization_996[0][0]
# __________________________________________________________________________________________________
# conv2d_988 (Conv2D)             (None, 16, 16, 128)  45056       activation_996[0][0]
# __________________________________________________________________________________________________
# batch_normalization_997 (BatchN (None, 16, 16, 128)  512         conv2d_988[0][0]
# __________________________________________________________________________________________________
# activation_997 (Activation)     (None, 16, 16, 128)  0           batch_normalization_997[0][0]
# __________________________________________________________________________________________________
# conv2d_989 (Conv2D)             (None, 16, 16, 32)   36864       activation_997[0][0]
# __________________________________________________________________________________________________
# concatenate_477 (Concatenate)   (None, 16, 16, 384)  0           concatenate_476[0][0]
#                                                                  conv2d_989[0][0]
# __________________________________________________________________________________________________
# batch_normalization_998 (BatchN (None, 16, 16, 384)  1536        concatenate_477[0][0]
# __________________________________________________________________________________________________
# activation_998 (Activation)     (None, 16, 16, 384)  0           batch_normalization_998[0][0]
# __________________________________________________________________________________________________
# conv2d_990 (Conv2D)             (None, 16, 16, 128)  49152       activation_998[0][0]
# __________________________________________________________________________________________________
# batch_normalization_999 (BatchN (None, 16, 16, 128)  512         conv2d_990[0][0]
# __________________________________________________________________________________________________
# activation_999 (Activation)     (None, 16, 16, 128)  0           batch_normalization_999[0][0]
# __________________________________________________________________________________________________
# conv2d_991 (Conv2D)             (None, 16, 16, 32)   36864       activation_999[0][0]
# __________________________________________________________________________________________________
# concatenate_478 (Concatenate)   (None, 16, 16, 416)  0           concatenate_477[0][0]
#                                                                  conv2d_991[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1000 (Batch (None, 16, 16, 416)  1664        concatenate_478[0][0]
# __________________________________________________________________________________________________
# activation_1000 (Activation)    (None, 16, 16, 416)  0           batch_normalization_1000[0][0]
# __________________________________________________________________________________________________
# conv2d_992 (Conv2D)             (None, 16, 16, 128)  53248       activation_1000[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1001 (Batch (None, 16, 16, 128)  512         conv2d_992[0][0]
# __________________________________________________________________________________________________
# activation_1001 (Activation)    (None, 16, 16, 128)  0           batch_normalization_1001[0][0]
# __________________________________________________________________________________________________
# conv2d_993 (Conv2D)             (None, 16, 16, 32)   36864       activation_1001[0][0]
# __________________________________________________________________________________________________
# concatenate_479 (Concatenate)   (None, 16, 16, 448)  0           concatenate_478[0][0]
#                                                                  conv2d_993[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1002 (Batch (None, 16, 16, 448)  1792        concatenate_479[0][0]
# __________________________________________________________________________________________________
# activation_1002 (Activation)    (None, 16, 16, 448)  0           batch_normalization_1002[0][0]
# __________________________________________________________________________________________________
# conv2d_994 (Conv2D)             (None, 16, 16, 128)  57344       activation_1002[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1003 (Batch (None, 16, 16, 128)  512         conv2d_994[0][0]
# __________________________________________________________________________________________________
# activation_1003 (Activation)    (None, 16, 16, 128)  0           batch_normalization_1003[0][0]
# __________________________________________________________________________________________________
# conv2d_995 (Conv2D)             (None, 16, 16, 32)   36864       activation_1003[0][0]
# __________________________________________________________________________________________________
# concatenate_480 (Concatenate)   (None, 16, 16, 480)  0           concatenate_479[0][0]
#                                                                  conv2d_995[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1004 (Batch (None, 16, 16, 480)  1920        concatenate_480[0][0]
# __________________________________________________________________________________________________
# activation_1004 (Activation)    (None, 16, 16, 480)  0           batch_normalization_1004[0][0]
# __________________________________________________________________________________________________
# conv2d_996 (Conv2D)             (None, 16, 16, 128)  61440       activation_1004[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1005 (Batch (None, 16, 16, 128)  512         conv2d_996[0][0]
# __________________________________________________________________________________________________
# activation_1005 (Activation)    (None, 16, 16, 128)  0           batch_normalization_1005[0][0]
# __________________________________________________________________________________________________
# conv2d_997 (Conv2D)             (None, 16, 16, 32)   36864       activation_1005[0][0]
# __________________________________________________________________________________________________
# concatenate_481 (Concatenate)   (None, 16, 16, 512)  0           concatenate_480[0][0]
#                                                                  conv2d_997[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1006 (Batch (None, 16, 16, 512)  2048        concatenate_481[0][0]
# __________________________________________________________________________________________________
# activation_1006 (Activation)    (None, 16, 16, 512)  0           batch_normalization_1006[0][0]
# __________________________________________________________________________________________________
# conv2d_998 (Conv2D)             (None, 16, 16, 256)  131072      activation_1006[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_25 (AveragePo (None, 8, 8, 256)    0           conv2d_998[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1007 (Batch (None, 8, 8, 256)    1024        average_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# activation_1007 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1007[0][0]
# __________________________________________________________________________________________________
# conv2d_999 (Conv2D)             (None, 8, 8, 128)    32768       activation_1007[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1008 (Batch (None, 8, 8, 128)    512         conv2d_999[0][0]
# __________________________________________________________________________________________________
# activation_1008 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1008[0][0]
# __________________________________________________________________________________________________
# conv2d_1000 (Conv2D)            (None, 8, 8, 32)     36864       activation_1008[0][0]
# __________________________________________________________________________________________________
# concatenate_482 (Concatenate)   (None, 8, 8, 288)    0           average_pooling2d_25[0][0]
#                                                                  conv2d_1000[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1009 (Batch (None, 8, 8, 288)    1152        concatenate_482[0][0]
# __________________________________________________________________________________________________
# activation_1009 (Activation)    (None, 8, 8, 288)    0           batch_normalization_1009[0][0]
# __________________________________________________________________________________________________
# conv2d_1001 (Conv2D)            (None, 8, 8, 128)    36864       activation_1009[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1010 (Batch (None, 8, 8, 128)    512         conv2d_1001[0][0]
# __________________________________________________________________________________________________
# activation_1010 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1010[0][0]
# __________________________________________________________________________________________________
# conv2d_1002 (Conv2D)            (None, 8, 8, 32)     36864       activation_1010[0][0]
# __________________________________________________________________________________________________
# concatenate_483 (Concatenate)   (None, 8, 8, 320)    0           concatenate_482[0][0]
#                                                                  conv2d_1002[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1011 (Batch (None, 8, 8, 320)    1280        concatenate_483[0][0]
# __________________________________________________________________________________________________
# activation_1011 (Activation)    (None, 8, 8, 320)    0           batch_normalization_1011[0][0]
# __________________________________________________________________________________________________
# conv2d_1003 (Conv2D)            (None, 8, 8, 128)    40960       activation_1011[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1012 (Batch (None, 8, 8, 128)    512         conv2d_1003[0][0]
# __________________________________________________________________________________________________
# activation_1012 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1012[0][0]
# __________________________________________________________________________________________________
# conv2d_1004 (Conv2D)            (None, 8, 8, 32)     36864       activation_1012[0][0]
# __________________________________________________________________________________________________
# concatenate_484 (Concatenate)   (None, 8, 8, 352)    0           concatenate_483[0][0]
#                                                                  conv2d_1004[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1013 (Batch (None, 8, 8, 352)    1408        concatenate_484[0][0]
# __________________________________________________________________________________________________
# activation_1013 (Activation)    (None, 8, 8, 352)    0           batch_normalization_1013[0][0]
# __________________________________________________________________________________________________
# conv2d_1005 (Conv2D)            (None, 8, 8, 128)    45056       activation_1013[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1014 (Batch (None, 8, 8, 128)    512         conv2d_1005[0][0]
# __________________________________________________________________________________________________
# activation_1014 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1014[0][0]
# __________________________________________________________________________________________________
# conv2d_1006 (Conv2D)            (None, 8, 8, 32)     36864       activation_1014[0][0]
# __________________________________________________________________________________________________
# concatenate_485 (Concatenate)   (None, 8, 8, 384)    0           concatenate_484[0][0]
#                                                                  conv2d_1006[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1015 (Batch (None, 8, 8, 384)    1536        concatenate_485[0][0]
# __________________________________________________________________________________________________
# activation_1015 (Activation)    (None, 8, 8, 384)    0           batch_normalization_1015[0][0]
# __________________________________________________________________________________________________
# conv2d_1007 (Conv2D)            (None, 8, 8, 128)    49152       activation_1015[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1016 (Batch (None, 8, 8, 128)    512         conv2d_1007[0][0]
# __________________________________________________________________________________________________
# activation_1016 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1016[0][0]
# __________________________________________________________________________________________________
# conv2d_1008 (Conv2D)            (None, 8, 8, 32)     36864       activation_1016[0][0]
# __________________________________________________________________________________________________
# concatenate_486 (Concatenate)   (None, 8, 8, 416)    0           concatenate_485[0][0]
#                                                                  conv2d_1008[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1017 (Batch (None, 8, 8, 416)    1664        concatenate_486[0][0]
# __________________________________________________________________________________________________
# activation_1017 (Activation)    (None, 8, 8, 416)    0           batch_normalization_1017[0][0]
# __________________________________________________________________________________________________
# conv2d_1009 (Conv2D)            (None, 8, 8, 128)    53248       activation_1017[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1018 (Batch (None, 8, 8, 128)    512         conv2d_1009[0][0]
# __________________________________________________________________________________________________
# activation_1018 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1018[0][0]
# __________________________________________________________________________________________________
# conv2d_1010 (Conv2D)            (None, 8, 8, 32)     36864       activation_1018[0][0]
# __________________________________________________________________________________________________
# concatenate_487 (Concatenate)   (None, 8, 8, 448)    0           concatenate_486[0][0]
#                                                                  conv2d_1010[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1019 (Batch (None, 8, 8, 448)    1792        concatenate_487[0][0]
# __________________________________________________________________________________________________
# activation_1019 (Activation)    (None, 8, 8, 448)    0           batch_normalization_1019[0][0]
# __________________________________________________________________________________________________
# conv2d_1011 (Conv2D)            (None, 8, 8, 128)    57344       activation_1019[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1020 (Batch (None, 8, 8, 128)    512         conv2d_1011[0][0]
# __________________________________________________________________________________________________
# activation_1020 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1020[0][0]
# __________________________________________________________________________________________________
# conv2d_1012 (Conv2D)            (None, 8, 8, 32)     36864       activation_1020[0][0]
# __________________________________________________________________________________________________
# concatenate_488 (Concatenate)   (None, 8, 8, 480)    0           concatenate_487[0][0]
#                                                                  conv2d_1012[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1021 (Batch (None, 8, 8, 480)    1920        concatenate_488[0][0]
# __________________________________________________________________________________________________
# activation_1021 (Activation)    (None, 8, 8, 480)    0           batch_normalization_1021[0][0]
# __________________________________________________________________________________________________
# conv2d_1013 (Conv2D)            (None, 8, 8, 128)    61440       activation_1021[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1022 (Batch (None, 8, 8, 128)    512         conv2d_1013[0][0]
# __________________________________________________________________________________________________
# activation_1022 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1022[0][0]
# __________________________________________________________________________________________________
# conv2d_1014 (Conv2D)            (None, 8, 8, 32)     36864       activation_1022[0][0]
# __________________________________________________________________________________________________
# concatenate_489 (Concatenate)   (None, 8, 8, 512)    0           concatenate_488[0][0]
#                                                                  conv2d_1014[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1023 (Batch (None, 8, 8, 512)    2048        concatenate_489[0][0]
# __________________________________________________________________________________________________
# activation_1023 (Activation)    (None, 8, 8, 512)    0           batch_normalization_1023[0][0]
# __________________________________________________________________________________________________
# conv2d_1015 (Conv2D)            (None, 8, 8, 128)    65536       activation_1023[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1024 (Batch (None, 8, 8, 128)    512         conv2d_1015[0][0]
# __________________________________________________________________________________________________
# activation_1024 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1024[0][0]
# __________________________________________________________________________________________________
# conv2d_1016 (Conv2D)            (None, 8, 8, 32)     36864       activation_1024[0][0]
# __________________________________________________________________________________________________
# concatenate_490 (Concatenate)   (None, 8, 8, 544)    0           concatenate_489[0][0]
#                                                                  conv2d_1016[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1025 (Batch (None, 8, 8, 544)    2176        concatenate_490[0][0]
# __________________________________________________________________________________________________
# activation_1025 (Activation)    (None, 8, 8, 544)    0           batch_normalization_1025[0][0]
# __________________________________________________________________________________________________
# conv2d_1017 (Conv2D)            (None, 8, 8, 128)    69632       activation_1025[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1026 (Batch (None, 8, 8, 128)    512         conv2d_1017[0][0]
# __________________________________________________________________________________________________
# activation_1026 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1026[0][0]
# __________________________________________________________________________________________________
# conv2d_1018 (Conv2D)            (None, 8, 8, 32)     36864       activation_1026[0][0]
# __________________________________________________________________________________________________
# concatenate_491 (Concatenate)   (None, 8, 8, 576)    0           concatenate_490[0][0]
#                                                                  conv2d_1018[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1027 (Batch (None, 8, 8, 576)    2304        concatenate_491[0][0]
# __________________________________________________________________________________________________
# activation_1027 (Activation)    (None, 8, 8, 576)    0           batch_normalization_1027[0][0]
# __________________________________________________________________________________________________
# conv2d_1019 (Conv2D)            (None, 8, 8, 128)    73728       activation_1027[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1028 (Batch (None, 8, 8, 128)    512         conv2d_1019[0][0]
# __________________________________________________________________________________________________
# activation_1028 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1028[0][0]
# __________________________________________________________________________________________________
# conv2d_1020 (Conv2D)            (None, 8, 8, 32)     36864       activation_1028[0][0]
# __________________________________________________________________________________________________
# concatenate_492 (Concatenate)   (None, 8, 8, 608)    0           concatenate_491[0][0]
#                                                                  conv2d_1020[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1029 (Batch (None, 8, 8, 608)    2432        concatenate_492[0][0]
# __________________________________________________________________________________________________
# activation_1029 (Activation)    (None, 8, 8, 608)    0           batch_normalization_1029[0][0]
# __________________________________________________________________________________________________
# conv2d_1021 (Conv2D)            (None, 8, 8, 128)    77824       activation_1029[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1030 (Batch (None, 8, 8, 128)    512         conv2d_1021[0][0]
# __________________________________________________________________________________________________
# activation_1030 (Activation)    (None, 8, 8, 128)    0           batch_normalization_1030[0][0]
# __________________________________________________________________________________________________
# conv2d_1022 (Conv2D)            (None, 8, 8, 32)     36864       activation_1030[0][0]
# __________________________________________________________________________________________________
# concatenate_493 (Concatenate)   (None, 8, 8, 640)    0           concatenate_492[0][0]
#                                                                  conv2d_1022[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1031 (Batch (None, 8, 8, 640)    2560        concatenate_493[0][0]
# __________________________________________________________________________________________________
# activation_1031 (Activation)    (None, 8, 8, 640)    0           batch_normalization_1031[0][0]
# __________________________________________________________________________________________________
# conv2d_1023 (Conv2D)            (None, 8, 8, 128)    81920       activation_1031[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_1068 (Batch (None, 4, 4, 704)    2816        concatenate_511[0][0]
# __________________________________________________________________________________________________
# activation_1068 (Activation)    (None, 4, 4, 704)    0           batch_normalization_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, 4, 4, 128)    90112       activation_1068[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1069 (Batch (None, 4, 4, 128)    512         conv2d_1060[0][0]
# __________________________________________________________________________________________________
# activation_1069 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1069[0][0]
# __________________________________________________________________________________________________
# conv2d_1061 (Conv2D)            (None, 4, 4, 32)     36864       activation_1069[0][0]
# __________________________________________________________________________________________________
# concatenate_512 (Concatenate)   (None, 4, 4, 736)    0           concatenate_511[0][0]
#                                                                  conv2d_1061[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1070 (Batch (None, 4, 4, 736)    2944        concatenate_512[0][0]
# __________________________________________________________________________________________________
# activation_1070 (Activation)    (None, 4, 4, 736)    0           batch_normalization_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1062 (Conv2D)            (None, 4, 4, 128)    94208       activation_1070[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1071 (Batch (None, 4, 4, 128)    512         conv2d_1062[0][0]
# __________________________________________________________________________________________________
# activation_1071 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1063 (Conv2D)            (None, 4, 4, 32)     36864       activation_1071[0][0]
# __________________________________________________________________________________________________
# concatenate_513 (Concatenate)   (None, 4, 4, 768)    0           concatenate_512[0][0]
#                                                                  conv2d_1063[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1072 (Batch (None, 4, 4, 768)    3072        concatenate_513[0][0]
# __________________________________________________________________________________________________
# activation_1072 (Activation)    (None, 4, 4, 768)    0           batch_normalization_1072[0][0]
# __________________________________________________________________________________________________
# conv2d_1064 (Conv2D)            (None, 4, 4, 128)    98304       activation_1072[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1073 (Batch (None, 4, 4, 128)    512         conv2d_1064[0][0]
# __________________________________________________________________________________________________
# activation_1073 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1065 (Conv2D)            (None, 4, 4, 32)     36864       activation_1073[0][0]
# __________________________________________________________________________________________________
# concatenate_514 (Concatenate)   (None, 4, 4, 800)    0           concatenate_513[0][0]
#                                                                  conv2d_1065[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1074 (Batch (None, 4, 4, 800)    3200        concatenate_514[0][0]
# __________________________________________________________________________________________________
# activation_1074 (Activation)    (None, 4, 4, 800)    0           batch_normalization_1074[0][0]
# __________________________________________________________________________________________________
# conv2d_1066 (Conv2D)            (None, 4, 4, 128)    102400      activation_1074[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1075 (Batch (None, 4, 4, 128)    512         conv2d_1066[0][0]
# __________________________________________________________________________________________________
# activation_1075 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1067 (Conv2D)            (None, 4, 4, 32)     36864       activation_1075[0][0]
# __________________________________________________________________________________________________
# concatenate_515 (Concatenate)   (None, 4, 4, 832)    0           concatenate_514[0][0]
#                                                                  conv2d_1067[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1076 (Batch (None, 4, 4, 832)    3328        concatenate_515[0][0]
# __________________________________________________________________________________________________
# activation_1076 (Activation)    (None, 4, 4, 832)    0           batch_normalization_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1068 (Conv2D)            (None, 4, 4, 128)    106496      activation_1076[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1077 (Batch (None, 4, 4, 128)    512         conv2d_1068[0][0]
# __________________________________________________________________________________________________
# activation_1077 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1077[0][0]
# __________________________________________________________________________________________________
# conv2d_1069 (Conv2D)            (None, 4, 4, 32)     36864       activation_1077[0][0]
# __________________________________________________________________________________________________
# concatenate_516 (Concatenate)   (None, 4, 4, 864)    0           concatenate_515[0][0]
#                                                                  conv2d_1069[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1078 (Batch (None, 4, 4, 864)    3456        concatenate_516[0][0]
# __________________________________________________________________________________________________
# activation_1078 (Activation)    (None, 4, 4, 864)    0           batch_normalization_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1070 (Conv2D)            (None, 4, 4, 128)    110592      activation_1078[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1079 (Batch (None, 4, 4, 128)    512         conv2d_1070[0][0]
# __________________________________________________________________________________________________
# activation_1079 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1071 (Conv2D)            (None, 4, 4, 32)     36864       activation_1079[0][0]
# __________________________________________________________________________________________________
# concatenate_517 (Concatenate)   (None, 4, 4, 896)    0           concatenate_516[0][0]
#                                                                  conv2d_1071[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1080 (Batch (None, 4, 4, 896)    3584        concatenate_517[0][0]
# __________________________________________________________________________________________________
# activation_1080 (Activation)    (None, 4, 4, 896)    0           batch_normalization_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1072 (Conv2D)            (None, 4, 4, 128)    114688      activation_1080[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1081 (Batch (None, 4, 4, 128)    512         conv2d_1072[0][0]
# __________________________________________________________________________________________________
# activation_1081 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1081[0][0]
# __________________________________________________________________________________________________
# conv2d_1073 (Conv2D)            (None, 4, 4, 32)     36864       activation_1081[0][0]
# __________________________________________________________________________________________________
# concatenate_518 (Concatenate)   (None, 4, 4, 928)    0           concatenate_517[0][0]
#                                                                  conv2d_1073[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1082 (Batch (None, 4, 4, 928)    3712        concatenate_518[0][0]
# __________________________________________________________________________________________________
# activation_1082 (Activation)    (None, 4, 4, 928)    0           batch_normalization_1082[0][0]
# __________________________________________________________________________________________________
# conv2d_1074 (Conv2D)            (None, 4, 4, 128)    118784      activation_1082[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1083 (Batch (None, 4, 4, 128)    512         conv2d_1074[0][0]
# __________________________________________________________________________________________________
# activation_1083 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1075 (Conv2D)            (None, 4, 4, 32)     36864       activation_1083[0][0]
# __________________________________________________________________________________________________
# concatenate_519 (Concatenate)   (None, 4, 4, 960)    0           concatenate_518[0][0]
#                                                                  conv2d_1075[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1084 (Batch (None, 4, 4, 960)    3840        concatenate_519[0][0]
# __________________________________________________________________________________________________
# activation_1084 (Activation)    (None, 4, 4, 960)    0           batch_normalization_1084[0][0]
# __________________________________________________________________________________________________
# conv2d_1076 (Conv2D)            (None, 4, 4, 128)    122880      activation_1084[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1085 (Batch (None, 4, 4, 128)    512         conv2d_1076[0][0]
# __________________________________________________________________________________________________
# activation_1085 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1077 (Conv2D)            (None, 4, 4, 32)     36864       activation_1085[0][0]
# __________________________________________________________________________________________________
# concatenate_520 (Concatenate)   (None, 4, 4, 992)    0           concatenate_519[0][0]
#                                                                  conv2d_1077[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1086 (Batch (None, 4, 4, 992)    3968        concatenate_520[0][0]
# __________________________________________________________________________________________________
# activation_1086 (Activation)    (None, 4, 4, 992)    0           batch_normalization_1086[0][0]
# __________________________________________________________________________________________________
# conv2d_1078 (Conv2D)            (None, 4, 4, 128)    126976      activation_1086[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1087 (Batch (None, 4, 4, 128)    512         conv2d_1078[0][0]
# __________________________________________________________________________________________________
# activation_1087 (Activation)    (None, 4, 4, 128)    0           batch_normalization_1087[0][0]
# __________________________________________________________________________________________________
# conv2d_1079 (Conv2D)            (None, 4, 4, 32)     36864       activation_1087[0][0]
# __________________________________________________________________________________________________
# concatenate_521 (Concatenate)   (None, 4, 4, 1024)   0           concatenate_520[0][0]
#                                                                  conv2d_1079[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1088 (Batch (None, 4, 4, 1024)   4096        concatenate_521[0][0]
# __________________________________________________________________________________________________
# activation_1088 (Activation)    (None, 4, 4, 1024)   0           batch_normalization_1088[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 1024)         0           activation_1088[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 100)          102500      global_average_pooling2d_8[0][0]
# ==================================================================================================
# Total params: 7,140,004
# Trainable params: 7,056,356
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
model.fit(
    train_dataset,
    epochs=4,
    validation_data=val_dataset,
    # callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
    # verbose=1
)
# Out:
# Epoch 1/4
# 2813/2813 [==============================] - 225s 70ms/step - loss: 3.9243 - accuracy: 0.1006 - val_loss: 3.5661 - val_accuracy: 0.1682
# Epoch 2/4
#  154/2813 [>.............................] - ETA: 2:50 - loss: 3.4315 - accuracy: 0.1765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 model.fit(
#       2     train_dataset,
#       3     epochs=4,
#       4     validation_data=val_dataset,
#       5     # callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
#       6     # verbose=1
#       7 )
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\engine\training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1177 with tf.profiler.experimental.Trace(
#    1178     'train',
#    1179     epoch_num=epoch,
#    1180     step_num=step,
#    1181     batch_size=batch_size,
#    1182     _r=1):
#    1183   callbacks.on_train_batch_begin(step)
# -> 1184   tmp_logs = self.train_function(iterator)
#    1185   if data_handler.should_sync:
#    1186     context.async_wait()
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\def_function.py:885, in Function.__call__(self, *args, **kwds)
#     882 compiler = "xla" if self._jit_compile else "nonXla"
#     884 with OptionalXlaContext(self._jit_compile):
# --> 885   result = self._call(*args, **kwds)
#     887 new_tracing_count = self.experimental_get_tracing_count()
#     888 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\def_function.py:917, in Function._call(self, *args, **kwds)
#     914   self._lock.release()
#     915   # In this case we have created variables on the first call, so we run the
#     916   # defunned version which is guaranteed to never create variables.
# --> 917   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918 elif self._stateful_fn is not None:
#     919   # Release the lock early so that multiple threads can perform the call
#     920   # in parallel.
#     921   self._lock.release()
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\function.py:3039, in Function.__call__(self, *args, **kwargs)
#    3036 with self._lock:
#    3037   (graph_function,
#    3038    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039 return graph_function._call_flat(
#    3040     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\function.py:1963, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1959 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1960 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1961     and executing_eagerly):
#    1962   # No tape is watching; skip to running the function.
# -> 1963   return self._build_call_outputs(self._inference_function.call(
#    1964       ctx, args, cancellation_manager=cancellation_manager))
#    1965 forward_backward = self._select_forward_and_backward_functions(
#    1966     args,
#    1967     possible_gradient_type,
#    1968     executing_eagerly)
#    1969 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, verbose=1)
print(f'Test accuracy: {test_accuracy:.4f}')
