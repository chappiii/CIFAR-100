# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from sklearn.preprocessing import OneHotEncoder

# 1. Load CIFAR-100 data
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')

# %%
# 2. One-hot encode the labels
enc = OneHotEncoder(sparse_output=False)
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

# %%
# 3. Define preprocessing function (resize + normalize)
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128])  
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# %%
# 4. Create tf.data.Dataset pipelines
batch_size = 64

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=1000)
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_dataset = test_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# 1. Load CIFAR-100 data
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')

# 2. One-hot encode the labels
enc = OneHotEncoder(sparse_output=False)
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

# 3. Define preprocessing function (resize + normalize)
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# 4. Shuffle training data before splitting
train_indices = np.arange(len(X_train))
np.random.shuffle(train_indices)

X_train = X_train[train_indices]
y_train = y_train[train_indices]

# 5. Compute split sizes
val_size = int(0.1 * len(X_train))
X_val = X_train[:val_size]
y_val = y_train[:val_size]
X_train = X_train[val_size:]
y_train = y_train[val_size:]

# 6. Create tf.data.Dataset pipelines
batch_size = 64

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=1000)
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_dataset = val_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size)
val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_dataset = test_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def conv_bn_act(x, filters, kernel_size, strides=1):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)  # or ReLU
    return x

def depthwise_separable_block(x, expand_filters, output_filters, strides=1):
    input_tensor = x

    # Expansion
    x = layers.Conv2D(expand_filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Depthwise conv
    x = layers.DepthwiseConv2D(3, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Squeeze-and-Excitation (simplified)
    se = layers.GlobalAveragePooling2D()(x)
    se = layers.Reshape((1, 1, expand_filters))(se)
    se = layers.Dense(expand_filters // 4, activation='swish')(se)
    se = layers.Dense(expand_filters, activation='sigmoid')(se)
    x = layers.Multiply()([x, se])

    # Projection
    x = layers.Conv2D(output_filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Skip connection
    if strides == 1 and input_tensor.shape[-1] == output_filters:
        x = layers.Add()([x, input_tensor])

    return x

def efficientnet_b0(input_shape=(128, 128, 3), num_classes=100):
    inputs = tf.keras.Input(shape=input_shape)
    x = conv_bn_act(inputs, 32, 3, strides=2)  # Stem

    # MBConv blocks
    x = depthwise_separable_block(x, 32, 16, strides=1)
    x = depthwise_separable_block(x, 96, 24, strides=2)
    x = depthwise_separable_block(x, 144, 24, strides=1)
    x = depthwise_separable_block(x, 144, 40, strides=2)
    x = depthwise_separable_block(x, 240, 40, strides=1)
    x = depthwise_separable_block(x, 240, 80, strides=2)
    x = depthwise_separable_block(x, 480, 80, strides=1)
    x = depthwise_separable_block(x, 480, 112, strides=1)
    x = depthwise_separable_block(x, 672, 112, strides=1)
    x = depthwise_separable_block(x, 672, 192, strides=2)
    x = depthwise_separable_block(x, 1152, 192, strides=1)
    x = depthwise_separable_block(x, 1152, 320, strides=1)

    # Head
    x = conv_bn_act(x, 1280, 1)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
model = efficientnet_b0()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   1024        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 64, 64, 32)   288         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           activation_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 32)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 8)      264         reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 32)     288         dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 64, 64, 32)   0           activation_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   512         multiply[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 96)   1536        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 96)   384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 96)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 32, 32, 96)   864         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 96)   384         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 96)           0           activation_4[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 96)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 24)     2328        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 96)     2400        dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 32, 32, 96)   0           activation_4[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 24)   2304        multiply_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 24)   96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 144)  3456        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 144)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 144)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 32, 32, 144)  1296        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 144)  576         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 144)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 144)          0           activation_6[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 144)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 36)     5220        reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 144)    5328        dense_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 32, 32, 144)  0           activation_6[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 24)   3456        multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 24)   96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 24)   0           batch_normalization_9[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 144)  3456        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 144)  576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 144)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 16, 16, 144)  1296        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 144)  576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 144)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 144)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 144)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 36)     5220        reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 144)    5328        dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 16, 16, 144)  0           activation_8[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 40)   5760        multiply_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 40)   160         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 240)  9600        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 240)  960         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 240)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 16, 16, 240)  2160        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 240)  960         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 240)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 240)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 240)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 60)     14460       reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 240)    14640       dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 16, 16, 240)  0           activation_10[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 40)   9600        multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 40)   160         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 40)   0           batch_normalization_15[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 240)  9600        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 240)  960         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 240)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 8, 8, 240)    2160        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 240)    960         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 240)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 240)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 240)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 60)     14460       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 240)    14640       dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 8, 8, 240)    0           activation_12[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 80)     19200       multiply_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 80)     320         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 480)    38400       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 480)    1920        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 480)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 8, 8, 480)    4320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 480)    1920        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 480)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 480)          0           activation_14[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 480)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 120)    57720       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 480)    58080       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 8, 8, 480)    0           activation_14[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 80)     38400       multiply_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 80)     320         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 80)     0           batch_normalization_21[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 480)    38400       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 480)    1920        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 480)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 8, 8, 480)    4320        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 480)    1920        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 480)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 480)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 480)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 120)    57720       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 480)    58080       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 8, 8, 480)    0           activation_16[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 112)    53760       multiply_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 112)    448         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 672)    75264       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 672)    2688        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 672)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 8, 8, 672)    6048        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 672)    2688        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 672)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 672)          0           activation_18[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 672)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 168)    113064      reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 672)    113568      dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 8, 8, 672)    0           activation_18[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 112)    75264       multiply_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 112)    448         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 112)    0           batch_normalization_27[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 672)    75264       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 672)    2688        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 672)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 4, 4, 672)    6048        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 672)    2688        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 672)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 672)          0           activation_20[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 672)    0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 168)    113064      reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 672)    113568      dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 4, 4, 672)    0           activation_20[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 192)    129024      multiply_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 192)    768         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 1152)   221184      batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 1152)   4608        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 1152)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 4, 4, 1152)   10368       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 1152)   4608        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 1152)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 1152)         0           activation_22[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 1152)   0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 288)    332064      reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 1152)   332928      dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 4, 4, 1152)   0           activation_22[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 192)    221184      multiply_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 192)    768         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 192)    0           batch_normalization_33[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 1152)   221184      add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 1152)   4608        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 1152)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 4, 4, 1152)   10368       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 1152)   4608        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 1152)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1152)         0           activation_24[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1152)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 288)    332064      reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 1152)   332928      dense_22[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 4, 4, 1152)   0           activation_24[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 320)    368640      multiply_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 320)    1280        conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 1280)   409600      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 1280)   5120        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 1280)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 1280)         0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1280)         0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 100)          128100      dropout[0][0]
# ==================================================================================================
# Total params: 4,367,204
# Trainable params: 4,340,100
# Non-trainable params: 27,104
# __________________________________________________________________________________________________

# %%
# # Then train with your resized CIFAR-100 data:
# model.fit(
#     X_train, y_train,
#     epochs=4,
#     batch_size=64,
#     validation_split=0.1,
#     callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
#     verbose=1
# )

# Train using the tf.data pipeline
model.fit(
    train_dataset,
    epochs=4,
    validation_data=val_dataset,
    # callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
    # verbose=1
)
# Out:
# Epoch 1/4
# 766/782 [============================>.] - ETA: 3s - loss: 1.6166 - accuracy: 0.5379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       1 # # Then train with your resized CIFAR-100 data:
#       2 # model.fit(
#       3 #     X_train, y_train,
#    (...)
#      10
#      11 # Train using the tf.data pipeline
# ---> 12 model.fit(
#      13     train_dataset,
#      14     epochs=4,
#      15     # validation_data=test_dataset,
#      16     callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)],
#      17     verbose=1
#      18 )
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\engine\training.py:1189, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187 logs = tmp_logs  # No error, now safe to assign to logs.
#    1188 end_step = step + data_handler.step_increment
# -> 1189 callbacks.on_train_batch_end(end_step, logs)
#    1190 if self.stop_training:
#    1191   break
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:435, in CallbackList.on_train_batch_end(self, batch, logs)
#     428 """Calls the `on_train_batch_end` methods of its callbacks.
#     429
#     430 Args:
#     431     batch: Integer, index of batch within the current epoch.
#     432     logs: Dict. Aggregated metric results up until this batch.
#     433 """
#     434 if self._should_call_train_batch_hooks:
# --> 435   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:295, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     293   self._call_batch_begin_hook(mode, batch, logs)
#     294 elif hook == 'end':
# --> 295   self._call_batch_end_hook(mode, batch, logs)
#     296 else:
#     297   raise ValueError('Unrecognized hook: {}'.format(hook))
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:315, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     312   batch_time = time.time() - self._batch_start_time
#     313   self._batch_times.append(batch_time)
# --> 315 self._call_batch_hook_helper(hook_name, batch, logs)
#     317 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     318   end_hook_name = hook_name
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:353, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     351 for callback in self.callbacks:
#     352   hook = getattr(callback, hook_name)
# --> 353   hook(batch, logs)
#     355 if self._check_timing:
#     356   if hook_name not in self._hook_times:
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:1028, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1027 def on_train_batch_end(self, batch, logs=None):
# -> 1028   self._batch_update_progbar(batch, logs)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:1100, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1096   self.seen += add_seen
#    1098 if self.verbose == 1:
#    1099   # Only block async when verbose = 1.
# -> 1100   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py:516, in sync_to_numpy_or_python_type(tensors)
#     513     return x.item() if np.ndim(x) == 0 else x
#     514   return t  # Don't turn ragged or sparse tensors to NumPy.
# --> 516 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py:512, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     510 def _to_single_numpy_or_python_type(t):
#     511   if isinstance(t, tf.Tensor):
# --> 512     x = t.numpy()
#     513     return x.item() if np.ndim(x) == 0 else x
#     514   return t
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py:1094, in _EagerTensorBase.numpy(self)
#    1071 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1072
#    1073 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1091     NumPy dtype.
#    1092 """
#    1093 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\chapp\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py:1060, in _EagerTensorBase._numpy(self)
#    1058 def _numpy(self):
#    1059   try:
# -> 1060     return self._numpy_internal()
#    1061   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062     six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, verbose=1)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 157/157 [==============================] - 7s 43ms/step - loss: 2.0457 - accuracy: 0.4508
# Test accuracy: 0.4508
